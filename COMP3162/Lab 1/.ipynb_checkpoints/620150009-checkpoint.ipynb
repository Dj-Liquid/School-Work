# %%
import pandas as pd
import numpy as np
#ID 620150009

# %%
df = pd.read_csv("csv/TestData.csv", encoding = "latin-1")

# %%
df.head()
# Out:
#    Rank                                   Name         Country  \
# 0   1.0     California Institute of Technology   United States
# 1   2.0                   University of Oxford  United Kingdom
# 2   3.0                    Stanford University   United States
# 3   4.0                University of Cambridge  United Kingdom
# 4   5.0  Massachusetts Institute of Technology   United States
#
#    Student Population  Students to Staff Ratio International Students  \
# 0                2243                      6.9                    26%
# 1               19920                     11.6                    34%
# 2               15596                      7.8                    22%
# 3               18810                     11.8                    34%
# 4               11074                      9.0                    33%
#
#   Female to Male Ratio  Overall Score  Teaching  Research Environment  \
# 0              33 : 67           95.2      95.6                  97.6
# ...

# %%
df.tail()
# Out:
#          Rank                                             Name  \
# 12425  1900.0                           Penza State University
# 12426  1901.0  Universidad Peruana de Ciencias Aplicadas (UPC)
# 12427  1902.0         Universidade Federal Rural do Semi-Arido
# 12428  1903.0                        State University of Bahia
# 12429  1904.0                            Tula State University
#
#                   Country  Student Population  Students to Staff Ratio  \
# 12425  Russian Federation               17934                     17.2
# 12426                Peru               56595                     21.1
# 12427              Brazil                8687                     12.4
# 12428              Brazil               25067                     11.9
# 12429  Russian Federation               18428                     35.0
#
#       International Students Female to Male Ratio  Overall Score  Teaching  \
# 12425                    12%             56:44:00        12.1935      14.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12430 entries, 0 to 12429
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     12430 non-null  float64
#  1   Name                     12430 non-null  object
#  2   Country                  12430 non-null  object
#  3   Student Population       12430 non-null  int64
#  4   Students to Staff Ratio  12430 non-null  float64
#  5   International Students   12430 non-null  object
#  6   Female to Male Ratio     11839 non-null  object
#  7   Overall Score            12430 non-null  float64
#  8   Teaching                 12430 non-null  float64
#  9   Research Environment     12430 non-null  float64
#  10  Research Quality         12430 non-null  float64
#  11  Industry Impact          12430 non-null  float64
#  12  International Outlook    12430 non-null  float64
#  13  Year                     12430 non-null  int64
# ...

# %%
df.isna()
# Out:
#         Rank   Name  Country  Student Population  Students to Staff Ratio  \
# 0      False  False    False               False                    False
# 1      False  False    False               False                    False
# 2      False  False    False               False                    False
# 3      False  False    False               False                    False
# 4      False  False    False               False                    False
# ...      ...    ...      ...                 ...                      ...
# 12425  False  False    False               False                    False
# 12426  False  False    False               False                    False
# 12427  False  False    False               False                    False
# 12428  False  False    False               False                    False
# 12429  False  False    False               False                    False
#
#        International Students  Female to Male Ratio  Overall Score  Teaching  \
# ...

# %%
df.isnull()
# Out:
#         Rank   Name  Country  Student Population  Students to Staff Ratio  \
# 0      False  False    False               False                    False
# 1      False  False    False               False                    False
# 2      False  False    False               False                    False
# 3      False  False    False               False                    False
# 4      False  False    False               False                    False
# ...      ...    ...      ...                 ...                      ...
# 12425  False  False    False               False                    False
# 12426  False  False    False               False                    False
# 12427  False  False    False               False                    False
# 12428  False  False    False               False                    False
# 12429  False  False    False               False                    False
#
#        International Students  Female to Male Ratio  Overall Score  Teaching  \
# ...

# %%
df.dropna()
# Out:
#          Rank                                             Name  \
# 0         1.0               California Institute of Technology
# 1         2.0                             University of Oxford
# 2         3.0                              Stanford University
# 3         4.0                          University of Cambridge
# 4         5.0            Massachusetts Institute of Technology
# ...       ...                                              ...
# 12425  1900.0                           Penza State University
# 12426  1901.0  Universidad Peruana de Ciencias Aplicadas (UPC)
# 12427  1902.0         Universidade Federal Rural do Semi-Arido
# 12428  1903.0                        State University of Bahia
# 12429  1904.0                            Tula State University
#
#                   Country  Student Population  Students to Staff Ratio  \
# 0           United States                2243                      6.9
# ...

# %%
df = df.rename(columns = {"Student Population":"Population"})

# %%
df.loc[df['Population']>20000, ['Name','Country']]
# Out:
#                                                     Name         Country
# 5                                     Harvard University   United States
# 12                    University of California, Berkeley   United States
# 13                                                   UCL  United Kingdom
# 14                                   Columbia University   United States
# 15                 University of California, Los Angeles   United States
# ...                                                  ...             ...
# 12416         University Abdelhamid Ibn Badis Mostaganem         Algeria
# 12418                                    Toyo University           Japan
# 12421  Pedagogical and Technological University of Co...        Colombia
# 12426    Universidad Peruana de Ciencias Aplicadas (UPC)            Peru
# 12428                          State University of Bahia          Brazil
#
# [5469 rows x 2 columns]

# %%
df.loc[(df['Students to Staff Ratio'] > 10) & (df['Overall Score'] > 60)]
# Out:
#         Rank                                Name         Country  Population  \
# 1        2.0                University of Oxford  United Kingdom       19920
# 3        4.0             University of Cambridge  United Kingdom       18810
# 7        8.0             Imperial College London  United Kingdom       15060
# 8        9.0                          ETH Zurich     Switzerland       18178
# 12      13.0  University of California, Berkeley   United States       36186
# ...      ...                                 ...             ...         ...
# 10702  177.0                University of Ottawa          Canada       38366
# 10703  178.0           Beijing Normal University           China       26439
# 10704  179.0                University of Exeter  United Kingdom       27190
# 10705  180.0                Macquarie University       Australia       30371
# 10706  181.0         Sapienza University of Rome           Italy       60522
#
# ...

# %%
df.groupby('Country')['Population'].mean()
# Out:
# Country
# Algeria          33813.369863
# Argentina        56339.222222
# Armenia          13838.000000
# Australia        23558.761755
# Austria          11543.613636
#                      ...
# United States    22724.506640
# Venezuela        28530.785714
# Vietnam          42765.739130
# Zambia           18939.500000
# Zimbabwe         22853.000000
# Name: Population, Length: 108, dtype: float64

# %%
df.groupby('Country')['Population'].sum()
# Out:
# Country
# Algeria           2468376
# Argentina         1521159
# Armenia             13838
# Australia         7515245
# Austria           1015838
#                    ...
# United States    34223107
# Venezuela          399431
# Vietnam            983612
# Zambia              37879
# Zimbabwe            45706
# Name: Population, Length: 108, dtype: int64

# %%
df.loc[df.groupby('Country')['Overall Score'].idxmax(), ['Country','Name','Overall Score']]
# Out:
#              Country                               Name  Overall Score
# 9165         Algeria    Ferhat Abbas Sétif University 1        43.7325
# 8207       Argentina  National University of San Martín        23.5600
# 12116        Armenia           Yerevan State University        21.0980
# 10562      Australia            University of Melbourne        79.1865
# 10644        Austria               University of Vienna        65.2270
# ...              ...                                ...            ...
# 10527  United States                Stanford University        97.9720
# 6789       Venezuela           Simón Bolívar University        18.5775
# 9157         Vietnam           Ton Duc Thang University        43.9850
# 9273          Zambia               University of Zambia        41.2125
# 9827        Zimbabwe             University of Zimbabwe        26.9375
#
# [108 rows x 3 columns]

# %%
df.groupby('Country')['Students to Staff Ratio'].mean()
# Out:
# Country
# Algeria          21.264384
# Argentina        17.377778
# Armenia           8.000000
# Australia        29.062382
# Austria          15.939773
#                    ...
# United States    14.629349
# Venezuela        16.450000
# Vietnam          21.891304
# Zambia           22.900000
# Zimbabwe         23.200000
# Name: Students to Staff Ratio, Length: 108, dtype: float64
